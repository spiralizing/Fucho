# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import sqlite3
import numpy as np
from numpy import random

# %%
#getting the database ordered
with sqlite3.connect('/home/alfredo/FuchoDatos/database.sqlite') as con:
    countries = pd.read_sql_query("SELECT * from Country", con)
    matches = pd.read_sql_query("SELECT * from Match", con)
    leagues = pd.read_sql_query("SELECT * from League", con)
    teams = pd.read_sql_query("SELECT * from Team", con)
    players = pd.read_sql_query("SELECT * from Player", con)
    t_att = pd.read_sql_query("SELECT * from Team_Attributes", con)
    p_att = pd.read_sql_query("SELECT * from Player_Attributes", con)

# %%
#now is time to get the fields of interest.
selected_countries = ['Spain', 'Germany', 'England'] #here you can select the countries you want to analyze
countries = countries[countries.name.isin(selected_countries)]
leagues = countries.merge(leagues,on='id',suffixes=('', '_y'))
matches = matches[matches.league_id.isin(leagues.id)]
teams = teams[teams.team_api_id.isin(matches.home_team_api_id)]

# %%
matches.iloc[1,55:77]
#players.player_api_id
# Out:
# home_player_1     23686
# home_player_2     26111
# home_player_3     38835
# home_player_4     30986
# home_player_5     31291
# home_player_6     31013
# home_player_7     30935
# home_player_8     39297
# home_player_9     26181
# home_player_10    30960
# home_player_11    36410
# away_player_1     36373
# away_player_2     36832
# away_player_3     23115
# away_player_4     37280
# away_player_5     24728
# away_player_6     24664
# away_player_7     31088
# away_player_8     23257
# away_player_9     24171
# away_player_10    25922
# away_player_11    27267
# Name: 1729, dtype: object

# %%
players[players.player_api_id.isin(matches.iloc[70,55:66])]
# Out:
#           id  player_api_id        player_name  player_fifa_api_id  \
# 1992    1995          30893  Cristiano Ronaldo               20801
# 2288    2291          24148    Darren Fletcher              138782
# 2661    2664          27430   Dimitar Berbatov               30110
# 2896    2900          30726  Edwin van der Sar               51539
# 4925    4930          30802       Ji-Sung Park               39943
# 7329    7340          34944    Michael Carrick               21146
# 7834    7846          30865      Nemanja Vidic              140601
# 8316    8329          32569       Patrice Evra               52091
# 8736    8750          38994             Rafael              210342
# 8982    8996          30620      Rio Ferdinand                7289
# 10733  10749          30829       Wayne Rooney               54050
#
#                   birthday  height  weight
# 1992   1985-02-05 00:00:00  185.42     176
# 2288   1984-02-01 00:00:00  182.88     163
# 2661   1981-01-30 00:00:00  187.96     165
# 2896   1970-10-29 00:00:00  198.12     196
# 4925   1981-02-25 00:00:00  177.80     161
# 7329   1981-07-28 00:00:00  187.96     163
# 7834   1981-10-21 00:00:00  190.50     194
# 8316   1981-05-15 00:00:00  175.26     163
# 8736   1990-07-09 00:00:00  175.26     152
# 8982   1978-11-07 00:00:00  193.04     190
# 10733  1985-10-24 00:00:00  175.26     183
